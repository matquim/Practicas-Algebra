# %% [markdown]
# # Práctica 1: Variables

# %% [markdown]
# ## Objetivos
#
# - Aprender a declarar variables, relacionando el tipo de dato con los sistemas numéricos.
# - Contrastar las sutiles diferencias de las variables algebráicas con las variables de programación.

# %% [markdown]
# ````{admonition} Concepto
# :class: tip
#
# Una `variable` almacena información. Nos interesa la información cuantitativa, la cuál en álgebra puede clasificarse como
# - Naturales
# - Enteros
# - Racionales
# - Irracionales
# - Reales
# - Complejos
#
# Una variable se declara como:
# ~~~python
# x = 4
# ~~~
#
# Python tiene su propia clasificacion de variables, por ejemplo:
# ~~~python
# # Enteros (Integers)
# x = 5
#
# # Punto Flotante (Float)
# y = 5.0
#
# # Complejos (Complex)
# z = 5 + 1j
# ~~~
# ````

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# **En el siguiente recuadro, copie y pegue el código de arriba para declarar las variables, recuerde dar "shift"+"enter" o Run.**

# %%
# Declare variables

# %% [markdown]
# Como ya habrá observado, toda línea que comience con el símbolo `#`se considera un `comentario`. Python ignorará esa línea y seguirá con la siguiente. Esto es útil para hacer anotaciones en el código.

# %% [markdown]
# Puede consultar el tipo de dato de una variable mediante `type`.
#
# Por ejemplo:
# ~~~python
# type(x)
# ~~~

# %% [markdown]
# **Pruebe a declarar diferentes tipos de variables y compruebe la diferencia entre 5 y 5.0.**

# %%
# Agregue código aquí

# %%
x = 5
type(x)

# %% [markdown]
# ````{admonition} Nota
# :class: note
# :class: margin
#
# Una variable de Python es algo mucho más general.
#
# Por ejemplo, podemos declarar la variable `carrito` y asignarle el número 7.3
# ```
# carrito = 7.3
# ```
#
# A lo largo del texto exploraremos otros tipos de variables.
# ````

# %% [markdown]
# ````{admonition} Operaciones
# :class: important
#
# Puede aplicar todas las operaciones matemáticas a las variables, por ejemplo:
#
# | Operación     |    Álgebra    |    Python    |
# |:-------------:|:-------------:|:------------:|
# |Suma           |     $z=x+y$   |       $z=x+y$|
# |Resta          |     $z=x-y$   |       $z=x-y$|
# |Multiplicación |   $z=(x)(y)$  |       $x=x*y$|
# |División       |$z=\frac{x}{y}$|       $z=x/y$|
# |Potencia       |     $z=x^{y}$ |      $z=x**y$|
#
# En nuestro ejemplo, podemos declarar una nueva variable, hacer las operaciones anteriores, guardar el resultado e imprimirlo.
# ~~~python
# #Declaramos la variable x
# x = 5.0
# #Declaramos la variable y
# y = 2.0
#
# #Hacemos algunas operaciones con nuestras variables x, y; y guardamos el resultado
# z_suma  = x+y
# z_resta = x-y
# z_mult  = x*y
# z_div   = x/y
# z_pot   = x**y
#
# #Imprimimos los resultados
# print("x",x,"y",y)
# print("suma",z_suma)
# print("resta",z_resta)
# print("multiplicación",z_mult)
# print("división",z_div)
# print("potencia",z_pot)
# ~~~
#
# Los resultados se almacenan en las variables z_suma, z_resta, z_mult y z_div. Es importante notar que una variable puede tener un nombre más largo que una sola letra; y que también podemos imprimir texto.
# ````

# %% [markdown]
# **En la siguiente celda:**
# - Declare las variables x=4, y=3.
# - Realice la operación x^2 + 3+y
# - Guarde el resultado en la variable z
# - Imprima el resultado

# %%
# Inserte código para resolver el ejercicio
