# %% [markdown]
# # Prácticas Álgebra Superior

# %% [markdown]
# Este libro digital busca ofrecer actividades computacionales pensadas para acompañar un curso inicial de Álgebra. En concreto, el material se alinea con el programa de la asignatura [`Álgebra Superior (Clave 1110)`](https://quimica.unam.mx/wp-content/uploads/2022/02/1110-Algebra-Superior-Q.pdf) de la Facultad de Química de la UNAM.
#
# A lo largo de las unidades centrales del curso, se proponen ejercicios que, además de introducir conceptos fundamentales de programación, emplean estas herramientas para profundizar y expandir las ideas clave del álgebra.

# %% [markdown]
# La estructura de este libro favorece la interactividad. Algunos bloques de código se presentan listos para copiar, pegar y ejecutar por ejemplo:
#
# ````{admonition} Aprendizaje de código
# :class: important
# ```
# print("Bienvenidos a Álgebra Superior")
# ```
# ````
#
# Mientras que otros bloques requieren que se complete el código.

# %% [markdown]
# A lo largo de los ejercicios encontrará celdas vacías con una nota para indicar que debe ser llenada siguiendo alguna instrucción, **como la siguiente**:

# %%
# Llene la siguiente celda con su código

# %% [markdown]
# En algunos casos, hay contenido oculto para revelarse con fines didácticos, como en la siguiente celda:

# %%
print("Bienvenidos al curso de Álgebra, Si está leyendo esto, el contenido oculto ha sido revelado.")
# Out:
# Bienvenidos a Álgebra Superior, esta es la respuesta oculta a una pregunta

# %% [markdown]
# ## Ejecución
#
# El código sugerido está escrito en Python. Para los fines didácticos que se persiguen, se recomienda su ejecución en `Google Colab`. Alternativamente, puede ser ejecutado desde la misma página de internet mediante el botón de `Live Code`, el cual es accesible desde el ícono con forma de `nave espacial` en la esquina superior derecha de las páginas.
#
# Recuerde que cada celda se ejecuta mediante las teclas **Shift** + **Enter** o mediante el botón *run* en `Live Code` o el tríangulo de *Play* en `Google Colab`.

# %% [markdown]
# Le deseamos mucho éxito y una pizca de suerte a lo largo de esta travecía.
