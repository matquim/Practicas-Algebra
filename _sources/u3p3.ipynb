# %% [markdown]
# # Práctica 3: Conjunto universal y complemento

# %% [markdown]
# ## Objetivo

# %% [markdown]
# ## Concepto Teórico

# %% [markdown]
# \subsubsection{Concepto teórico}
#
# El conjunto universal $U$ contiene todos los elementos considerados.
#
# El complemento se define como:
# \[
# A^c = U - A
# \]
#
# \subsubsection{Ejemplo}
#
# \begin{lstlisting}
# A = {"a","b","c"}
# B = {"+","x","="}
# C = {1,2,3}
#
# U = A | B | C
#
# print("Complemento de A:", U - A)
# \end{lstlisting}
#
# \subsubsection{Ejercicios}
#
# \begin{enumerate}[label=\alph*)]
#     \item Definir $A$ y $B$.
#     \item Construir $U$.
#     \item Calcular $A^c$ y $B^c$.
# \end{enumerate}
