# %% [markdown]
# # Práctica 8: Aplicaciones

# %% [markdown]
# ## Objetivo

# %% [markdown]
# ## Concepto Teórico

# %% [markdown]
# \subsubsection{Ejercicios propuestos}
#
# \begin{enumerate}[label=\alph*)]
#     \item Calcular la fuerza resultante de tres vectores fuerza.
#     \item Calcular el trabajo $W = F \cdot d$.
#     \item Calcular el área de un triángulo usando producto cruz.
#     \item Calcular el volumen de un paralelepípedo:
#     \[
#     |u \cdot (v \times w)|
#     \]
#     \item Calcular los ángulos interiores de un triángulo en $\mathbb{R}^3$.
# \end{enumerate}
#
# %--------------------------------------------------
#
# \subsection{Visualización (opcional)}
#
# \begin{lstlisting}
# import matplotlib.pyplot as plt
# import numpy as np
#
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
#
# a = np.array([2,3,1])
# b = np.array([-1,2,4])
# origin = np.array([0,0,0])
#
# ax.quiver(*origin, *a)
# ax.quiver(*origin, *b)
#
# plt.show()
# \end{lstlisting}
