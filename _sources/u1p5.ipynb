# %% [markdown]
# # Práctica 5: Combinaciones

# %% [markdown]
# ## Objetivo

# %% [markdown]
# ## Concepto Teórico
#
# Las combinaciones se calculan como:
#
# \begin{equation}
# C(n,k) = \frac{n!}{k!(n-k)!}
# \end{equation}

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# - Calcular $C(10,2)$

# %%
# Coloque su código aquí

# %% [markdown]
# - Calcular $C(100,4)$

# %%
# Coloque su código aquí

# %% [markdown]
# - Calcular $C(500,3)$

# %%
# Coloque su código aquí
