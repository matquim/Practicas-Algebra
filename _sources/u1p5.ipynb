# %% [markdown]
# # Práctica 5: Combinaciones

# %% [markdown]
# ## Objetivo

# %% [markdown]
# ````{admonition} Concepto
# :class: tip
#
# Las combinaciones se calculan como:
#
# \begin{equation}
# C(n,k) = \frac{n!}{k!(n-k)!}
# \end{equation}
# ````

# %% [markdown]
# ## Ejercicios
#
# ````{admonition} Sugerencia
# :class: note, margin
#
# Recuerde la función para factorial
# ~~~python
# math.factorial(n)
# ~~~
# ````

# %% [markdown]
# - Calcule $C(10,2)$. SUgerencia. Utilice el c

# %%
# Coloque su código aquí

# %%
import math
math.factorial(10)/(math.factorial(3)*math.factorial(10-3))
# Out:
# 120.0

# %% [markdown]
# - Calcular $C(100,4)$

# %%
# Coloque su código aquí

# %% [markdown]
# - Calcular $C(500,3)$

# %%
# Coloque su código aquí

# %% [markdown]
# Utilice la función combinatoria de la librería math para calcular C(100,4)

# %%
# Coloque su código aquí

# %%
math.comb(100, 4)
