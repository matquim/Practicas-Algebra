# %% [markdown]
# # Aplicación al cálculo de sumas y series

# %% [markdown]
# ## Objetivo
#
# Calcular sumas utilizando programación y compararlas con fórmulas analíticas.

# %% [markdown]
# ````{admonition} Concepto
# :class: tip
#
# ## Concepto Teórico
#
# Se sabe que el resultado de la suma de los primeros $n$ números naturales es:
#
# \begin{equation}
# \sum_{i=1}^{n} i = \frac{n(n+1)}{2}
# \end{equation}
# ````

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# ### Ejemplo 1
#
# Implemente un código que calcule esta suma y utilícelo para calcular los valores de la suma cuando $n=20,100,10000$. Compare con el resultado analítico de la ecuación anterior.

# %%
# Escriba código aquí

# %%
# Comparacion sin usar funciones
for n in [20, 100, 10000]:
    suma = 0
    for i in range(1,n+1):
        suma += i

    suma_analitica = n*(n+1)//2

    print("n =", n)
    print("Suma numerica:", suma)
    print("Suma analitica:", suma_analitica)
    print("Diferencia:", suma - suma_analitica)
    print()

# %% [markdown]
# **Nota:** La expresión analítica de la suma de los primeros $n$ números naturales es $S = \frac{n(n+1)}{2}$.

# %% [markdown]
# ### Ejemplo 1 más complejo: usando funciones
#
# Ahora use funciones:

# %%
# Escriba código aquí

# %%
# Funcion para la suma numerica
def suma_numerica(n):
    suma = 0
    for i in range(1,n+1):
        suma += i
    return suma

# Funcion para la solucion analitica
def suma_analitica(n):
    return n*(n+1)//2

# Comparacion
for n in [20, 100, 10000]:
    print("n =", n)
    print("Suma numerica:", suma_numerica(n))
    print("Suma analitica:", suma_analitica(n))
    print("Diferencia:", suma_numerica(n) - suma_analitica(n))
    print()

# %% [markdown]
# **Nota:** El uso de funciones permite reutilizar código y hacer el programa más claro y modular.
#
# ## Ejercicios propuestos
#
# - Calcular la suma para $n = 20, 100, 10000$.
# - Comparar el resultado numérico con la fórmula analítica.

# %%
# Agregue código aquí
