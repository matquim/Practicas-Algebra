# %% [markdown]
# # Práctica 3: Factorial

# %% [markdown]
# ## Objetivo
#
# Implementar el cálculo del factorial sin usar funciones predefinidas.

# %% [markdown]
# ## Concepto Teórico
#
# El factorial de un número $n$ se define como:
#
# \begin{equation}
# n! = 1 \cdot 2 \cdot 3 \cdots n
# \end{equation}

# %% [markdown]
# ## Ejemplo
#
# ~~~python
# # Calculo del factorial de 4
# n = 4
# factorial = 1
#
# for i in range(1, n+1):
#     factorial *= i
#
# print("Factorial:", factorial)
# ~~~
#
# ## Ejercicios propuestos
#
# - Calcular el factorial de diferentes valores de $n$.
# - Comparar con la función \texttt{math.factorial()}.
# - Desarrolle un código que imprima las tablas de multiplicar del 1 al 10.
